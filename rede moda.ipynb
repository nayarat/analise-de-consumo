# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
base_url = 'https://raw.githubusercontent.com/LucasFDutra/analise-de-consumo/master/consumo'

# %%
#abril_06 = np.genfromtxt(base_url + '/2016/04-abril.csv', delimiter=';')

maio_06 = np.genfromtxt(base_url + '/2016/05-maio.csv', delimiter=';')
junho_06 = np.genfromtxt(base_url + '/2016/06-junho.csv', delimiter=';')
julho_06 = np.genfromtxt(base_url + '/2016/07-julho.csv', delimiter=';')
agosto_06 = np.genfromtxt(base_url + '/2016/08-agosto.csv', delimiter=';')
setembro_06 = np.genfromtxt(base_url + '/2016/09-setembro.csv', delimiter=';')
outubro_06 = np.genfromtxt(base_url + '/2016/10-outubro.csv', delimiter=';')
novembro_06 = np.genfromtxt(base_url + '/2016/11-novembro.csv', delimiter=';')
dezembro_06 = np.genfromtxt(base_url + '/2016/12-dezembro.csv', delimiter=';')

# %%
janeiro_07 = np.genfromtxt(base_url + '/2017/01-janeiro.csv', delimiter=';')
fevereiro_07 = np.genfromtxt(base_url + '/2017/02-fevereiro.csv', delimiter=';')
marco_07 = np.genfromtxt(base_url + '/2017/03-marco.csv', delimiter=';')
abril_07 = np.genfromtxt(base_url + '/2017/04-abril.csv', delimiter=';')
maio_07 = np.genfromtxt(base_url + '/2017/05-maio.csv', delimiter=';')
junho_07 = np.genfromtxt(base_url + '/2017/06-junho.csv', delimiter=';')

# %%
# colocar arquivos de 2018
janeiro_08 = np.genfromtxt(base_url + '/2018/01-janeiro.csv', delimiter=';')
fevereiro_08 = np.genfromtxt(base_url + '/2018/02-fevereiro.csv', delimiter=';')
marco_08 = np.genfromtxt(base_url + '/2018/03-marco.csv', delimiter=';')
abril_08 = np.genfromtxt(base_url + '/2018/04-abril.csv', delimiter=';')
maio_08 = np.genfromtxt(base_url + '/2018/05-maio.csv', delimiter=';')
junho_08 = np.genfromtxt(base_url + '/2018/06-junho.csv', delimiter=';')
julho_08 = np.genfromtxt(base_url + '/2018/07-julho.csv', delimiter=';')
agosto_08 = np.genfromtxt(base_url + '/2018/08-agosto.csv', delimiter=';')
setembro_08 = np.genfromtxt(base_url + '/2018/09-setembro.csv', delimiter=';')
outubro_08 = np.genfromtxt(base_url + '/2018/10-outubro.csv', delimiter=';')
novembro_08 = np.genfromtxt(base_url + '/2018/11-novembro.csv', delimiter=';')
dezembro_08 = np.genfromtxt(base_url + '/2018/12-dezembro.csv', delimiter=';')

# %%
#dados 2019
janeiro_09 = np.genfromtxt(base_url + '/2019/01-janeiro.csv', delimiter=';')

# %%
maio_06 = pd.DataFrame(maio_06[:, 2])
junho_06 = pd.DataFrame(junho_06[:, 2])
julho_06 = pd.DataFrame(julho_06[:, 2])
agosto_06 = pd.DataFrame(agosto_06[:, 2])
setembro_06 = pd.DataFrame(setembro_06[:, 2])
outubro_06 = pd.DataFrame(outubro_06[:, 2])
novembro_06 = pd.DataFrame(novembro_06[:, 2])
dezembro_06 = pd.DataFrame(dezembro_06[:, 2])

# %%
janeiro_07 = pd.DataFrame(janeiro_07[:, 2])
fevereiro_07 = pd.DataFrame(fevereiro_07[:, 2])
marco_07 = pd.DataFrame(marco_07[:, 2])
abril_07 = pd.DataFrame(abril_07[:, 2])
maio_07 = pd.DataFrame(maio_07[:, 2])
junho_07 = pd.DataFrame(junho_07[:, 2])

# %%
janeiro_08 = pd.DataFrame(janeiro_08[:, 2])
fevereiro_08 = pd.DataFrame(fevereiro_08[:, 2])
marco_08 = pd.DataFrame(marco_08[:, 2])
abril_08 = pd.DataFrame(abril_08[:, 2])
maio_08 = pd.DataFrame(maio_08[:, 2])
junho_08 = pd.DataFrame(junho_08[:, 2])
julho_08 = pd.DataFrame(julho_08[:, 2])
agosto_08 = pd.DataFrame(agosto_08[:, 2])
setembro_08 = pd.DataFrame(setembro_08[:, 2])
outubro_08 = pd.DataFrame(outubro_08[:, 2])
novembro_08 = pd.DataFrame(novembro_08[:, 2])
dezembro_08 = pd.DataFrame(dezembro_08[:, 2])

# %%
janeiro_09 = pd.DataFrame(janeiro_09[:, 2])

# %%
moda_maio_06 = maio_06.mode().median()
# Out:
# 0    0.2766
# dtype: float64

# %%
moda_maio_06 = maio_06.mode().median()
maio_06.update(maio_06.fillna(moda_maio_06))

moda_junho_06 = junho_06.mode().median()
junho_06.update(junho_06.fillna(moda_junho_06))

moda_julho_06 = julho_06.mode().median()
julho_06.update(julho_06.fillna(moda_julho_06))

moda_agosto_06 = agosto_06.mode().median()
agosto_06.update(agosto_06.fillna(moda_agosto_06))

moda_setembro_06 = setembro_06.mode().median()
setembro_06.update(setembro_06.fillna(moda_setembro_06))

moda_outubro_06 = outubro_06.mode().median()
outubro_06.update(outubro_06.fillna(moda_outubro_06))

moda_novembro_06 = novembro_06.mode().median()
novembro_06.update(novembro_06.fillna(moda_novembro_06))

moda_dezembro_06 = dezembro_06.mode().median()
dezembro_06.update(dezembro_06.fillna(moda_dezembro_06))

# %%
moda_janeiro_07 = janeiro_07.mode().median()
janeiro_07.update(janeiro_07.fillna(moda_janeiro_07))

moda_fevereiro_07 = fevereiro_07.mode().median()
fevereiro_07.update(fevereiro_07.fillna(moda_fevereiro_07))

moda_marco_07 = marco_07.mode().median()
marco_07.update(marco_07.fillna(moda_marco_07))

moda_abril_07 = abril_07.mode().median()
abril_07.update(abril_07.fillna(moda_abril_07))

moda_maio_07 = maio_07.mode().median()
maio_07.update(maio_07.fillna(moda_maio_07))

moda_junho_07 = junho_07.mode().median()
junho_07.update(junho_07.fillna(moda_junho_07))

# %%
moda_janeiro_08 = janeiro_08.mode().median()
janeiro_08.update(janeiro_08.fillna(moda_janeiro_08))

moda_fevereiro_08 = fevereiro_08.mode().median()
fevereiro_08.update(fevereiro_08.fillna(moda_fevereiro_08))

moda_marco_08 = marco_08.mode().median()
marco_08.update(marco_08.fillna(moda_marco_08))

moda_abril_08 = abril_08.mode().median()
abril_08.update(abril_08.fillna(moda_abril_08))

moda_maio_08 = maio_08.mode().median()
maio_08.update(maio_08.fillna(moda_maio_08))

moda_junho_08 = junho_08.mode().median()
junho_08.update(junho_08.fillna(moda_junho_08))

moda_julho_08 = julho_08.mode().median()
julho_08.update(julho_08.fillna(moda_julho_08))

moda_agosto_08 = agosto_08.mode().median()
agosto_08.update(agosto_08.fillna(moda_agosto_08))

moda_setembro_08 = setembro_08.mode().median()
setembro_08.update(setembro_08.fillna(moda_setembro_08))

moda_outubro_08 = outubro_08.mode().median()
outubro_08.update(outubro_08.fillna(moda_outubro_08))

moda_novembro_08 = novembro_08.mode().median()
novembro_08.update(novembro_08.fillna(moda_novembro_08))

moda_dezembro_08 = dezembro_08.mode().median()
dezembro_08.update(dezembro_08.fillna(moda_dezembro_08))

# %%
moda_janeiro_09 = janeiro_09.mode().median()
janeiro_09.update(janeiro_09.fillna(moda_janeiro_09))

# %%
maio_06 = maio_06.iloc[::-1]
junho_06 = junho_06.iloc[::-1]
julho_06 = julho_06.iloc[::-1]
agosto_06 = agosto_06.iloc[::-1]
setembro_06 = setembro_06.iloc[::-1]
outubro_06 = outubro_06.iloc[::-1]
novembro_06 = novembro_06.iloc[::-1]
dezembro_06 = dezembro_06.iloc[::-1]

# %%
janeiro_07 = janeiro_07.iloc[::-1]
fevereiro_07 = fevereiro_07.iloc[::-1]
marco_07 = marco_07.iloc[::-1]
abril_07 = abril_07.iloc[::-1]
maio_07 = maio_07.iloc[::-1]
junho_07 = junho_07.iloc[::-1]

# %%
janeiro_08 = janeiro_08.iloc[::-1]
fevereiro_08 = fevereiro_08.iloc[::-1]
marco_08 = marco_08.iloc[::-1]
abril_08 = abril_08.iloc[::-1]
maio_08 = maio_08.iloc[::-1]
junho_08 = junho_08.iloc[::-1]
julho_08 = julho_08.iloc[::-1]
agosto_08 = agosto_08.iloc[::-1]
setembro_08 = setembro_08.iloc[::-1]
outubro_08 = outubro_08.iloc[::-1]
novembro_08 = novembro_08.iloc[::-1]
dezembro_08 = dezembro_08.iloc[::-1]

# %%
janeiro_09 = janeiro_09.iloc[::-1]

# %%
# criando DataFrame de 2016
data2016 = pd.concat([maio_06, junho_06, julho_06, agosto_06,
                      setembro_06, outubro_06, novembro_06, dezembro_06], ignore_index=True)

# criando DataFrame de 2017
data2017 = pd.concat([janeiro_07, fevereiro_07, marco_07,
                      abril_07, maio_07, junho_07], ignore_index=True)

# %%
# criando DataFrame de 2018
data2018 = pd.concat([janeiro_08, fevereiro_08, marco_08,
                      abril_08, maio_08, junho_08, julho_08, agosto_08,
                      setembro_08, outubro_08, novembro_08, dezembro_08], ignore_index=True)

# %%
# criando DataFrame de 2019
data2019 = pd.concat([janeiro_09], ignore_index=True)

# %%
# plotando 2016
plt.figure(figsize=(20,10))
plt.plot(maio_06)
plt.plot(junho_06)
plt.plot(julho_06)
plt.plot(agosto_06)
plt.plot(setembro_06)
plt.plot(outubro_06)
plt.plot(novembro_06)
plt.plot(dezembro_06)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data2016)
plt.title('grafico do ano de 2016')
plt.show()

# %%
# plotando 2017
plt.figure(figsize=(20,10))
plt.plot(janeiro_07)
plt.plot(fevereiro_07)
plt.plot(marco_07)
plt.plot(abril_07)
plt.plot(maio_07)
plt.plot(junho_07)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data2017)
plt.title('grafico do ano de 2017')
plt.show()

# %%
#plot de 2018 por mes
plt.figure(figsize=(20,10))
plt.plot(janeiro_08)
plt.plot(fevereiro_08)
plt.plot(marco_08)
plt.plot(abril_08)
plt.plot(maio_08)
plt.plot(junho_08)
plt.plot(julho_08)
plt.plot(agosto_08)
plt.plot(setembro_08)
plt.plot(outubro_08)
plt.plot(novembro_08)
plt.plot(dezembro_08)
plt.show()

# %%
#plot de 2018 ano todo
plt.figure(figsize=(20,10))
plt.plot(data2018)
plt.title('grafico do ano de 2018')
plt.show()

# %%
#plot de 2019 por mes
plt.figure(figsize=(20,10))
plt.plot(janeiro_09)
plt.show()

# %%
#plot de 2019 ano todo
plt.figure(figsize=(20,10))
plt.plot(data2019)
plt.title('grafico do ano de 2019')
plt.show()

# %% [markdown]
# # **Regressão de 2016**

# %%
grauDoPolinomio = 5

ano = data2016

x = np.linspace(0,ano.size-1, ano.size)
x = x.reshape(x.size,1)

# #-------------------------------Biblioteca------------------------------------#
from sklearn.preprocessing import PolynomialFeatures

# #--------------------Elevando as entradas a ordem degree----------------------#
poly = PolynomialFeatures(degree=grauDoPolinomio) # cada atributo será elevado a 1, 2, 3 e 4 criando assim 3 novos atributos, esse número é definido por escolha do programador
x = poly.fit_transform(x)

# #---------------------------Criando o regressor-------------------------------#
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, ano)

# #----Ver a correlação do modelo com relação a base de dados de Treinamento----#
score = regressor.score(x, ano)
print('A correlação do modelo com a base de dados de treinamento é de: {}'.format(score))

# #------------------------------Prevendo um valor------------------------------#
previsoes = regressor.predict(x)

# #------------------Diferança entre valores reais e previstos------------------#
from sklearn.metrics import mean_absolute_error, mean_squared_error
erro_absoluto = mean_absolute_error(ano, previsoes)
erro_quadratico = mean_squared_error(ano, previsoes)
print('Erro absoluto: {}'.format(erro_absoluto))
print('Erro quadratico: {}'.format(erro_quadratico))

previsoes_2016 = previsoes
# Out:
# A correlação do modelo com a base de dados de treinamento é de: 0.08576838748512394
# Erro absoluto: 0.06992003802759264
# Erro quadratico: 0.0072887996993359514

# %%
plt.figure(figsize=(20,10))
plt.plot(ano)
plt.plot(previsoes, 'red')
plt.show()

# %% [markdown]
# # **Regressão de 2017**

# %%
 grauDoPolinomio = 5

ano = data2017

x = np.linspace(0,ano.size-1, ano.size)
x = x.reshape(x.size,1)

#-------------------------------Biblioteca------------------------------------#
from sklearn.preprocessing import PolynomialFeatures

#--------------------Elevando as entradas a ordem degree----------------------#
poly = PolynomialFeatures(degree=grauDoPolinomio) # cada atributo será elevado a 1, 2, 3 e 4 criando assim 3 novos atributos, esse número é definido por escolha do programador
x = poly.fit_transform(x)

#---------------------------Criando o regressor-------------------------------#
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, ano)

#----Ver a correlação do modelo com relação a base de dados de Treinamento----#
score = regressor.score(x, ano)
print('A correlação do modelo com a base de dados de treinamento é de: {}'.format(score))

#------------------------------Prevendo um valor------------------------------#
previsoes = regressor.predict(x)

#------------------Diferança entre valores reais e previstos------------------#
from sklearn.metrics import mean_absolute_error, mean_squared_error
erro_absoluto = mean_absolute_error(ano, previsoes)
erro_quadratico = mean_squared_error(ano, previsoes)
print('Erro absoluto: {}'.format(erro_absoluto))
print('Erro quadratico: {}'.format(erro_quadratico))

previsoes_2017 = previsoes
# Out:
# A correlação do modelo com a base de dados de treinamento é de: 0.014404234719186946
# Erro absoluto: 0.08131029954014271
# Erro quadratico: 0.010438591336694444

# %%
plt.figure(figsize=(20,10))
plt.plot(ano)
plt.plot(previsoes, 'red')
plt.show()

# %% [markdown]
# # Regressão de 2018

# %%
grauDoPolinomio = 5

ano = data2018

x = np.linspace(0,ano.size-1, ano.size)
x = x.reshape(x.size,1)

#-------------------------------Biblioteca------------------------------------#
from sklearn.preprocessing import PolynomialFeatures

#--------------------Elevando as entradas a ordem degree----------------------#
poly = PolynomialFeatures(degree=grauDoPolinomio) # cada atributo será elevado a 1, 2, 3 e 4 criando assim 3 novos atributos, esse número é definido por escolha do programador
x = poly.fit_transform(x)

#---------------------------Criando o regressor-------------------------------#
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, ano)

#----Ver a correlação do modelo com relação a base de dados de Treinamento----#
score = regressor.score(x, ano)
print('A correlação do modelo com a base de dados de treinamento é de: {}'.format(score))

#------------------------------Prevendo um valor------------------------------#
previsoes = regressor.predict(x)

#------------------Diferança entre valores reais e previstos------------------#
from sklearn.metrics import mean_absolute_error, mean_squared_error
erro_absoluto = mean_absolute_error(ano, previsoes)
erro_quadratico = mean_squared_error(ano, previsoes)
print('Erro absoluto: {}'.format(erro_absoluto))
print('Erro quadratico: {}'.format(erro_quadratico))

previsoes_2018 = previsoes
# Out:
# A correlação do modelo com a base de dados de treinamento é de: 0.06675269023004804
# Erro absoluto: 30.496847453774226
# Erro quadratico: 1393.881863265975

# %%
plt.figure(figsize=(20,10))
plt.plot(ano)
plt.plot(previsoes, 'red')
plt.show()

# %% [markdown]
# # **Regressão de 2019**

# %%
grauDoPolinomio = 5

ano = data2019

x = np.linspace(0,ano.size-1, ano.size)
x = x.reshape(x.size,1)

#-------------------------------Biblioteca------------------------------------#
from sklearn.preprocessing import PolynomialFeatures

#--------------------Elevando as entradas a ordem degree----------------------#
poly = PolynomialFeatures(degree=grauDoPolinomio) # cada atributo será elevado a 1, 2, 3 e 4 criando assim 3 novos atributos, esse número é definido por escolha do programador
x = poly.fit_transform(x)

#---------------------------Criando o regressor-------------------------------#
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, ano)

#----Ver a correlação do modelo com relação a base de dados de Treinamento----#
score = regressor.score(x, ano)
print('A correlação do modelo com a base de dados de treinamento é de: {}'.format(score))

#------------------------------Prevendo um valor------------------------------#
previsoes = regressor.predict(x)

#------------------Diferança entre valores reais e previstos------------------#
from sklearn.metrics import mean_absolute_error, mean_squared_error
erro_absoluto = mean_absolute_error(ano, previsoes)
erro_quadratico = mean_squared_error(ano, previsoes)
print('Erro absoluto: {}'.format(erro_absoluto))
print('Erro quadratico: {}'.format(erro_quadratico))

previsoes_2019 = previsoes

# %%
plt.figure(figsize=(20,10))
plt.plot(ano)
plt.plot(previsoes, 'red')
plt.show()

# %% [markdown]
# # Concatenar anos

# %%
anos = np.concatenate((previsoes_2016, previsoes_2017, previsoes_2018, previsoes_2019))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-50ddbd4107da> in <module>()
# ----> 1 anos = np.concatenate((previsoes_2016, previsoes_2017, previsoes_2018, previsoes_2019))
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Criando rede neural

# %%
import tensorflow as tf

# %%
# Base de treinamento
x = []
y = []
batch = 32 # quantidade de termos que serão agrupados

# Agrupando os termos
for i in range(len(anos)-batch):
    lista = []
    for j in range(batch):
        lista.append(anos[i+j][0])
    x.append(lista)
    y.append(anos[i+batch])

# %%
# Transformando em numpy array
x = np.asarray(x)  
y = np.asarray(y)

# %%
train_len = int(x.shape[0]*0.8)
test_len = x.shape[0] - train_len

# %%
x_train = x[0:train_len]
y_train = y[0:train_len]

# %%
x_test = x[train_len:]
y_test = y[train_len:]

# %%
model = tf.keras.models.Sequential()

# 1º Bloco
model.add(tf.keras.layers.CuDNNLSTM(100, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(tf.keras.layers.Dropout(0.2))

# 2º Bloco
model.add(tf.keras.layers.CuDNNLSTM(units=100, return_sequences = True))
model.add(tf.keras.layers.Dropout(0.2))

# 3º Bloco
model.add(tf.keras.layers.CuDNNLSTM(units=100, return_sequences = True))
model.add(tf.keras.layers.Dropout(0.2))

# 4º Bloco
model.add(tf.keras.layers.CuDNNLSTM(units=100))
model.add(tf.keras.layers.Dropout(0.2))

# Saída
model.add(tf.keras.layers.Dense(1, activation='linear'))

# Visualizar estrutura da rede
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm (CuDNNLSTM)       (None, 32, 100)           41200
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 100)           0
# _________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)     (None, 32, 100)           80800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 100)           0
# _________________________________________________________________
# cu_dnnlstm_2 (CuDNNLSTM)     (None, 32, 100)           80800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 100)           0
# _________________________________________________________________
# cu_dnnlstm_3 (CuDNNLSTM)     (None, 100)               80800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 283,701
# Trainable params: 283,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop',
             loss='mse')

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
#Treinamento da rede neural
model.fit(x_train, y_train, epochs=100, batch_size=32, callbacks=[tf.keras.callbacks.ReduceLROnPlateau(monitor='loss')])
# Out:
# Train on 60205 samples
# Epoch 1/100
# 60205/60205 [==============================] - 89s 1ms/sample - loss: 977.2279
# Epoch 2/100
# 60205/60205 [==============================] - 81s 1ms/sample - loss: 33.6255
# Epoch 3/100
# 60205/60205 [==============================] - 81s 1ms/sample - loss: 26.6104
# Epoch 4/100
# 51200/60205 [========================>.....] - ETA: 12s - loss: 24.1286
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-c9908316f916> in <module>()
# ----> 1 model.fit(x_train, y_train, epochs=100, batch_size=32, callbacks=[tf.keras.callbacks.ReduceLROnPlateau(monitor='loss')])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
previstos = model.predict(x_test)

# %%
plt.plot(previstos, 'red', label='previsto')
plt.plot(y_test, 'blue', label='real')
plt.legend()

# %% [markdown]
# ## Salvando o modelo
